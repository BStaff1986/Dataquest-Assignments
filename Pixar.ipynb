# %% [markdown]
# # Visualizing Pixar's Rollercoaster
#
# This guided project intended to provide some practice with more advanced data visualization features relative to the previous recent_grads project. The dataset for this project contain information about Pixar movies including the release year, critic scores, and money grossed.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pixar_movies = pd.read_csv('PixarMovies.csv')
print("Rows: " + str(pixar_movies.shape[0]))
print("Columns: " + str(pixar_movies.shape[1]))
pixar_movies
# Out:
# Rows: 15
# Columns: 16
#     Year Released                Movie  Length  RT Score  IMDB Score  \
# 0            1995            Toy Story      81       100         8.3
# 1            1998         A Bug's Life      96        92         7.2
# 2            1999          Toy Story 2      92       100         7.9
# 3            2001       Monsters, Inc.      90        96         8.1
# 4            2003         Finding Nemo     104        99         8.2
# 5            2004      The Incredibles     115        97         8.0
# 6            2006                 Cars     116        74         7.2
# 7            2007          Ratatouille     111        96         8.0
# 8            2008               WALL-E      97        96         8.4
# 9            2009                   Up      96        98         8.3
# 10           2010          Toy Story 3     103        99         8.4
# 11           2011               Cars 2     113        39         6.3
# 12           2012                Brave     100        78         7.2
# 13           2013  Monsters University     107        78         7.4
# 14           2015           Inside Out     102        98         8.8
#
#     Metacritic Score  Opening Weekend  Worldwide Gross  Domestic Gross  \
# 0                 92            29.14            362.0           191.8
# 1                 77            33.26            363.4           162.8
# 2                 88            57.39            485.0           245.9
# 3                 78            62.58            528.8           255.9
# 4                 90            70.25            895.6           339.7
# 5                 90            70.47            631.4           261.4
# 6                 73            60.12            462.0           244.1
# 7                 96            47.00            623.7           206.4
# 8                 94            63.10            521.3           223.8
# 9                 88            68.11            731.3           293.0
# 10                92           110.31           1063.2           415.0
# 11                57           109.00            559.9           191.5
# 12                69            66.30            539.0           237.3
# 13                65            82.43            743.6           268.5
# 14                93            90.40            677.1           340.5
#
#     Adjusted Domestic Gross  International Gross Domestic % International %  \
# 0                    356.21                170.2     52.98%          47.02%
# 1                    277.18                200.6     44.80%          55.20%
# 2                    388.43                239.2     50.70%          49.32%
# 3                    366.12                272.9     48.39%          51.61%
# 4                    457.46                555.9     37.93%          62.07%
# 5                    341.28                370.0     41.40%          58.60%
# 6                    302.59                217.9     52.84%          47.16%
# 7                    243.65                417.3     33.09%          66.91%
# 8                    253.11                297.5     42.93%          57.07%
# 9                    318.90                438.3     40.07%          59.93%
# 10                   423.88                648.2     39.03%          60.97%
# 11                   194.43                368.4     34.20%          65.80%
# 12                   243.39                301.7     44.03%          55.97%
# 13                   269.59                475.1     36.11%          63.89%
# 14                   340.50                336.6     50.29%          49.71%
#
#     Production Budget  Oscars Nominated  Oscars Won
# 0                  30               3.0         0.0
# 1                  45               1.0         0.0
# 2                  90               1.0         0.0
# 3                 115               3.0         1.0
# 4                  94               4.0         1.0
# 5                  92               4.0         2.0
# 6                  70               2.0         0.0
# 7                 150               5.0         1.0
# 8                 180               6.0         1.0
# 9                 175               5.0         2.0
# 10                200               5.0         2.0
# 11                200               0.0         0.0
# 12                185               1.0         1.0
# 13                200               0.0         0.0
# 14                175               NaN         NaN

# %% [markdown]
# # Clean the Data
# Within the dataset, there are a few problems with the formatting of the data.
#
# For instance, the percentage of domestic and international profits are currently strings with percent signs. These will need to be cleared and their data type will need to be switched to float.

# %%
# Convert domestic/intl percentage to floats
pixar_movies['Domestic %'] = pixar_movies['Domestic %'].str.rstrip('%').astype(float)
pixar_movies['International %'] = pixar_movies['International %'].str.rstrip('%').astype(float)

# Normalize the IMDB Scores
pixar_movies['IMDB Score'] = pixar_movies['IMDB Score'] * 10

# Use the movie names as the index
pixar_movies.set_index(pixar_movies["Movie"], inplace=True)

pixar_movies
# Out:
#                      Year Released                Movie  Length  RT Score  \
# Movie
# Toy Story                     1995            Toy Story      81       100
# A Bug's Life                  1998         A Bug's Life      96        92
# Toy Story 2                   1999          Toy Story 2      92       100
# Monsters, Inc.                2001       Monsters, Inc.      90        96
# Finding Nemo                  2003         Finding Nemo     104        99
# The Incredibles               2004      The Incredibles     115        97
# Cars                          2006                 Cars     116        74
# Ratatouille                   2007          Ratatouille     111        96
# WALL-E                        2008               WALL-E      97        96
# Up                            2009                   Up      96        98
# Toy Story 3                   2010          Toy Story 3     103        99
# Cars 2                        2011               Cars 2     113        39
# Brave                         2012                Brave     100        78
# Monsters University           2013  Monsters University     107        78
# Inside Out                    2015           Inside Out     102        98
#
#                      IMDB Score  Metacritic Score  Opening Weekend  \
# Movie
# Toy Story                  83.0                92            29.14
# A Bug's Life               72.0                77            33.26
# Toy Story 2                79.0                88            57.39
# Monsters, Inc.             81.0                78            62.58
# Finding Nemo               82.0                90            70.25
# The Incredibles            80.0                90            70.47
# Cars                       72.0                73            60.12
# Ratatouille                80.0                96            47.00
# WALL-E                     84.0                94            63.10
# Up                         83.0                88            68.11
# Toy Story 3                84.0                92           110.31
# Cars 2                     63.0                57           109.00
# Brave                      72.0                69            66.30
# Monsters University        74.0                65            82.43
# Inside Out                 88.0                93            90.40
#
#                      Worldwide Gross  Domestic Gross  Adjusted Domestic Gross  \
# Movie
# Toy Story                      362.0           191.8                   356.21
# A Bug's Life                   363.4           162.8                   277.18
# Toy Story 2                    485.0           245.9                   388.43
# Monsters, Inc.                 528.8           255.9                   366.12
# Finding Nemo                   895.6           339.7                   457.46
# The Incredibles                631.4           261.4                   341.28
# Cars                           462.0           244.1                   302.59
# Ratatouille                    623.7           206.4                   243.65
# WALL-E                         521.3           223.8                   253.11
# Up                             731.3           293.0                   318.90
# Toy Story 3                   1063.2           415.0                   423.88
# Cars 2                         559.9           191.5                   194.43
# Brave                          539.0           237.3                   243.39
# Monsters University            743.6           268.5                   269.59
# Inside Out                     677.1           340.5                   340.50
#
#                      International Gross  Domestic %  International %  \
# Movie
# Toy Story                          170.2       52.98            47.02
# A Bug's Life                       200.6       44.80            55.20
# Toy Story 2                        239.2       50.70            49.32
# Monsters, Inc.                     272.9       48.39            51.61
# Finding Nemo                       555.9       37.93            62.07
# The Incredibles                    370.0       41.40            58.60
# Cars                               217.9       52.84            47.16
# Ratatouille                        417.3       33.09            66.91
# WALL-E                             297.5       42.93            57.07
# Up                                 438.3       40.07            59.93
# Toy Story 3                        648.2       39.03            60.97
# Cars 2                             368.4       34.20            65.80
# Brave                              301.7       44.03            55.97
# Monsters University                475.1       36.11            63.89
# Inside Out                         336.6       50.29            49.71
#
#                      Production Budget  Oscars Nominated  Oscars Won
# Movie
# Toy Story                           30               3.0         0.0
# A Bug's Life                        45               1.0         0.0
# Toy Story 2                         90               1.0         0.0
# Monsters, Inc.                     115               3.0         1.0
# Finding Nemo                        94               4.0         1.0
# The Incredibles                     92               4.0         2.0
# Cars                                70               2.0         0.0
# Ratatouille                        150               5.0         1.0
# WALL-E                             180               6.0         1.0
# Up                                 175               5.0         2.0
# Toy Story 3                        200               5.0         2.0
# Cars 2                             200               0.0         0.0
# Brave                              185               1.0         1.0
# Monsters University                200               0.0         0.0
# Inside Out                         175               NaN         NaN

# %%
critic_reviews = pixar_movies[['RT Score', 'IMDB Score', 'Metacritic Score']]
ax = critic_reviews.plot(figsize=(20,6))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f963bb6d05d3> in <module>()
#       1 critic_reviews = pixar_movies[['RT Score', 'IMDB Score', 'Metacritic Score']]
#       2 ax = critic_reviews.plot(figsize=(20,6))
# ----> 3 ax.set_xticks(pixar_movies.index)
#       4 print(pixar_movies.index)
#       5 plt.show()
#
# C:\Users\Bryan\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    2848         ACCEPTS: sequence of floats
#    2849         """
# -> 2850         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    2851         self.stale = True
#    2852         return ret
#
# C:\Users\Bryan\Anaconda3\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1596             xleft, xright = self.get_view_interval()
#    1597             if xright > xleft:
# -> 1598                 self.set_view_interval(min(ticks), max(ticks))
#    1599             else:
#    1600                 self.set_view_interval(max(ticks), min(ticks))
#
# C:\Users\Bryan\Anaconda3\lib\site-packages\matplotlib\axis.py in set_view_interval(self, vmin, vmax, ignore)
#    1927             Vmin, Vmax = self.get_view_interval()
#    1928             if Vmin < Vmax:
# -> 1929                 self.axes.viewLim.intervalx = (min(vmin, vmax, Vmin),
#    1930                                                max(vmin, vmax, Vmax))
#    1931             else:
#
# TypeError: unorderable types: numpy.ndarray() < str()

# %% [markdown]
# Note: In this guided project, we practiced using pandas' matplotlib wrapper to create plots. While the wrapper makes it simpler to create a graph it lacks the same customization and control that comes with using matplotlib directly. Using the simpler method here left us without all the xtick labels and without an easy way to see which movie was responsible for the huge drop in critic scores.
#
# It was Cars 2.

# %% [markdown]
# While the graph above was lacking some important information, it still did reveal some interesting things. For instance, the three lines move across the graph in lanes with Rotten Tomato scores consistently being the most favourable to the Pixar movies. To explore this further we will use pandas to create a box and whisker plot.

# %%
critics_reviews.plot(kind='box', figsize=(9,5))
plt.show()

# %% [markdown]
# Another interesting area we can explore with this Pixar dataset is the balance between international and domestic revenues for each film. To do this, we will create a stacked bar plot using pandas. We will also count which movies made more internationally/domestically and, finally, what percentage of Pixar's overall revenue has come from home and abroad.

# %%
revenue_proportions = pixar_movies[['Domestic %', 'International %']]
ax = revenue_proportions.plot(kind='bar', stacked=True)
ax.axhline(y=50, alpha=0.5, c='k')
plt.show()

domestic = 0
international = 0
domestic_sum = 0
international_sum = 0
for index, row in revenue_proportions.iterrows():
    # How many movies generated more revenue domestically?
    if row['Domestic %'] > row['International %']:
        domestic += 1
    elif row['International %'] > row['Domestic %']:
        international += 1
    
     # What is the total share over all Pixar movies in the dataset?
    domestic_sum += row['Domestic %']
    international_sum += row['International %']
        
    
print('Domestic: ' + str(domestic))
print("International: " + str(international) + '\n')
print('Domestic share for all movies: ' + str(round(domestic_sum/14,2)))
print('International share for all movies:' + str(round(international_sum/14,2)))
# Out:
# Domestic: 4
# International: 11
#
# Domestic share for all movies: 46.34
# International share for all movies:60.8

# %% [markdown]
# The black line is draw at 50%. Four movies grossed more domestically and overall Pixar's domestic gross is 46% of their total revenue.
